# %% [markdown]
# # Import data

# %%
import pandas as pd
from pandas import DataFrame as df
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
#Load data from csv and store it in a dataframe
data = pd.read_csv("haberman.csv")

# %%
# We show the first individuals
data.head() # Return the first n rows
# Out:
#    Age  Year_of_op  Nbr_of_nodes  Surv_status
# 0   30          64             1            1
# 1   30          62             3            1
# 2   30          65             0            1
# 3   31          59             2            1
# 4   31          65             4            1

# %% [markdown]
# - Age = Age of patient at time of operation (numerical)
# - Year_of_op = Patient's year of operation (year - 1900, numerical)
# - Nbr_of_nodes = Number of positive axillary nodes detected (numerical)
# - Surv_status = Survival status (class attribute); 1 = the patient survived 5 years or longer, 2 = the patient died within 5 year

# %% [markdown]
# # Data set description

# %%
print(data.shape)
# Out:
# (306, 4)

# %%
data.dtypes
# Out:
# Age             int64
# Year_of_op      int64
# Nbr_of_nodes    int64
# Surv_status     int64
# dtype: object

# %% [markdown]
# All the values of the dataset are integers.

# %%
data.columns
# Out:
# Index(['Age', 'Year_of_op', 'Nbr_of_nodes', 'Surv_status'], dtype='object')

# %% [markdown]
# # Statistics

# %%
data.describe()
# Out:
#               Age  Year_of_op  Nbr_of_nodes  Surv_status
# count  306.000000  306.000000    306.000000   306.000000
# mean    52.457516   62.852941      4.026144     1.264706
# std     10.803452    3.249405      7.189654     0.441899
# min     30.000000   58.000000      0.000000     1.000000
# 25%     44.000000   60.000000      0.000000     1.000000
# 50%     52.000000   63.000000      1.000000     1.000000
# 75%     60.750000   65.750000      4.000000     2.000000
# max     83.000000   69.000000     52.000000     2.000000

# %%
print(data.nunique())
# Out:
# Age             49
# Year_of_op      12
# Nbr_of_nodes    31
# Surv_status      2
# dtype: int64

# %%
data["Surv_status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: Surv_status, dtype: int64

# %% [markdown]
# Because there is different amount of values one and two in survival status column, we have to construt the training data the way that there is same amount of values one and two in training dataset. Because in other case our model will classify value one more often than value two.

# %% [markdown]
# # Analyse

# %% [markdown]
# ### Histograms

# %%
data.hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# From the figures above we can see that:
# - Age variable is more or less normally distributed with mean 52 years and standard deviation 10 years.
# - Year of operation is more uniformly distributed variable whom range is from 58 to 69 years.
# - From the distribution of Number of nodes variable we can see that in most of cases number of positive axillary nodes detected has been lower than 5.
# - From the distribution of Survival status variable we can see that majority of patients have survived 5 or more years after surgery.

# %% [markdown]
# # Boxplots

# %%
boxplot = data.boxplot(grid=True, rot=60, fontsize=8)

# %% [markdown]
# From this figure we can search the outliers of the data. The only variable where we can notice outliers seems to be Number of nodes. When investigating more precisely those outliers we can see that some of them has value over 30 and even over 40. Because in total human has 20-30 axillary nodes it is only possible to have max. 20-30 cancer cell positive axillary nodes. Because of that all the outliers with a value over 30 should be wrong values.

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# Searching all the observations with a value over 30 in the Number of nodes column:

# %%
a = data[data["Nbr_of_nodes"] > 30]
print(a)
# Out:
#      Age  Year_of_op  Nbr_of_nodes  Surv_status
# 62    43          58            52            2
# 174   54          67            46            1
# 215   59          62            35            2

# %% [markdown]
# As we mentioned above we have some wrong values in Number of Nodes column. Because there is only three observation which has value over 30 in that column the easiest way is just to remove them. In this case removing those three observation is okay but if there would be more observations with wrong value the removing method wouldn't be the best one because then we would miss too much data.

# %%
# removing those three observations:
data = data.drop([62, 174, 215])

# %%
boxplot = data.boxplot(grid=True, rot=60, fontsize=8)

# %% [markdown]
# Even though after removing those three observations we still have some outliers in the Number of node column. However we are not going to remove or modify those observations because first of all there is lot of outliers and second of all the outliers are pretty close to each others. From the figure we can see them to constructing a line.

# %% [markdown]
# # Scatter plots

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = 'Surv_status')

# %% [markdown]
# From these two scatter plots we can study the correlation between variables (or columns) of the data. When analysing those figures we can realise that it is really hard to find any kind of correlation between any of the variables. That is a good thing because highly correlated variables causes bias in a model. If we would have strong correlation between variables we should remove some of them.

# %% [markdown]
# # Grouping

# %%
data.groupby(["Surv_status"]).mean()
# Out:
#                    Age  Year_of_op  Nbr_of_nodes
# Surv_status
# 1            52.008929   62.843750      2.598214
# 2            53.746835   62.898734      6.544304

# %% [markdown]
# It seems that the average age and year of operation does not differ almost at all in different survival status groups but the average number of nodes differs quite a much. This result indicates that patient's age and the year of operation wouldn't have as much influence to the survial status than number of nodes detected.

# %% [markdown]
# # Dealing with missing values

# %%
data.isnull().sum()
# Out:
# Age             0
# Year_of_op      0
# Nbr_of_nodes    0
# Surv_status     0
# dtype: int64

# %%
(data == 0).sum(axis=0)
# Out:
# Age               0
# Year_of_op        0
# Nbr_of_nodes    136
# Surv_status       0
# dtype: int64

# %% [markdown]
# No missing values in our dataset

# %% [markdown]
# # Dividing the data into training and testing data

# %% [markdown]
# Before training the model we have to divide the dataset into training dataset and testing dataset. We use the training dataset to train the model and testing dataset to test the performance of the model.

# %% [markdown]
# Before splitting the data into training and testing datasets we have to divide the data into input and output variables. Because we try to classify with our model whether patient's survival status is more than five years or less than five years using the data of the patient's age, number of positive cancer nodes and the year of cancer operation, our input variables are the Age, Year_of_op and Nbr_of_nodes and the output variable is Surv_status variable.

# %%
# Input and output data:
X = data.loc[:, :"Nbr_of_nodes"] # input vriables
Y = data.loc[:,"Surv_status"] # output variables
print("Input data:\n", X.head())
print("\nOutput data:\n", Y.head())
# Out:
# Input data:
#     Age  Year_of_op  Nbr_of_nodes
# 0   30          64             1
# 1   30          62             3
# 2   30          65             0
# 3   31          59             2
# 4   31          65             4
#
# Output data:
#  0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Surv_status, dtype: int64

# %%
# Shuffling input and output data:
from sklearn.utils import shuffle

Xs, Ys = shuffle(X, Y, random_state = 19)
print("Shuffled input data:\n" + str(Xs.head()))
print("\nShuffled output data:\n" + str(Ys.head()))
# Out:
# Shuffled input data:
#      Age  Year_of_op  Nbr_of_nodes
# 138   51          64             7
# 27    38          60             0
# 8     34          66             9
# 191   56          66             3
# 139   51          59             1
#
# Shuffled output data:
# 138    1
# 27     1
# 8      2
# 191    2
# 139    1
# Name: Surv_status, dtype: int64

# %%
# Splitting the dataset into training and testing data:
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(Xs, Ys, random_state = 20) # using the defalut value for the observation
# percentage of the training subset which is 75% of the original dataset

# checking the distributions of the training and testing data:
X_train.hist(figsize=(6, 6), bins=50, xlabelsize=6, ylabelsize=6) # input data of the training dataset
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Year_of_op'}>],
#        [<AxesSubplot:title={'center':'Nbr_of_nodes'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
X_test.hist(figsize=(6, 6), bins=50, xlabelsize=6, ylabelsize=6) # input data of the testing dataset
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Year_of_op'}>],
#        [<AxesSubplot:title={'center':'Nbr_of_nodes'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# From the figures above we can see that the distributions of the input variables in training and testing datasets looks the same, which is good thing, because then we know that the splitting of the dataset splitted also the information in the original dataset equally.

# %%
Y_train.hist(figsize=(3,3)) # output data of the training dataset
# Out:
# <AxesSubplot:>

# %%
Y_test.hist(figsize=(3,3)) # output data of the testing dataset
# Out:
# <AxesSubplot:>

# %% [markdown]
# Also the distribution of the output variable in the training and testing datasets looks the same.

# %% [markdown]
# # Dealing with imbalance classes

# %% [markdown]
# From the figures above we can see that in both output datasets (Y_train and Y_test) there is different amount of variables with the value one and two. If we do nothing to that we will have problems, because if we train the model using inbalanced output data the model will give more likely results like the dominant output in the training data. Because of that we have to balance our training dataset. We also have to balance the testing dataset because later when we compute the figure of merits of the different model we have to have equal amount of two classes in testing data.

# %% [markdown]
# To balance our datasets we use SMOTE method.

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state=3)
x_train_smote, y_train_smote = sm.fit_resample(X_train, Y_train)
x_test_smote, y_test_smote = sm.fit_resample(X_test, Y_test)
print("Output column in training data:\n" + str(y_train_smote.value_counts()))
print("\nOutput column in testing data:\n" + str(y_test_smote.value_counts()))
# Out:
# Output column in training data:
# 2    163
# 1    163
# Name: Surv_status, dtype: int64
#
# Output column in testing data:
# 1    61
# 2    61
# Name: Surv_status, dtype: int64

# %% [markdown]
# Above we can see that after balancing the datasets we have equal amount of observations with the value one and two in the output columns.

# %%
# checking if the distributions of the input variables in the datasets are somehow the same:
x_train_smote.hist(figsize=(6,6), bins=50, xlabelsize=6, ylabelsize=6) # dataset after SMOTE
X_train.hist(figsize=(6, 6), bins=50, xlabelsize=6, ylabelsize=6) # dataset befoe SMOTE
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Year_of_op'}>],
#        [<AxesSubplot:title={'center':'Nbr_of_nodes'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# checking if the distributions of the input variables in the training dataset remained the same as before:
x_test_smote.hist(figsize=(6,6), bins=50, xlabelsize=6, ylabelsize=6) # dataset after SMOTE
X_test.hist(figsize=(6, 6), bins=50, xlabelsize=6, ylabelsize=6) # dataset befoe SMOTE
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Year_of_op'}>],
#        [<AxesSubplot:title={'center':'Nbr_of_nodes'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# This checking of the distributions isn't mandatory because of the way SMOTE method balances the classes, but at least now we can be sure.

# %% [markdown]
# # Normalizing the data

# %% [markdown]
# Because after training the model we want to compare the input variables' regression coefficients, we should normalize the data. If we don't normalize the data, the coefficients are not comparable because the coefficients of the variables depends then also of the size ranges of the variables' values.

# %% [markdown]
# First we normalize the input variables of the training data and after that we normalize the input variables of the testing data using the same mean and standard deviation as when we were normalizing the training data.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train_smote)
X_train_bal_norm = scaler.transform(x_train_smote)
X_test_norm = scaler.transform(x_test_smote)

# %% [markdown]
# # Building the ML models

# %% [markdown]
# Now we are ready to start to implement the ML model. As we told above our mission is to classify with our model if the patient will survive more or less than five years by using patient's age, number of positive cancer nodes and year of cancer operation as an input data. Because our output variable is discrete and has only two classes we can use the logistic regression model.

# %% [markdown]
# Nevertheless before starting to train the model we have to recode our output variable to have only values 0 or 1 because the logistic regression model can only give values 0 or 1 as an output.

# %%
# recoding the output variables
Y_train = y_train_smote.replace([1, 2], [0, 1])
Y_test = y_test_smote.replace([1, 2], [0, 1])

# simplifying the variables' names
X_train = X_train_bal_norm
X_test = X_test_norm

# %% [markdown]
# **Next we will build four logistic regression models; normal logistic regression model, logistic ridge regression, logistic lasso regression and logistic elastic net regression. After training those models we evaluate them using the testing dataset and after all we will make a conclusion of the best model.**

# %% [markdown]
# # Normal logistic regression:

# %%
from sklearn.linear_model import LogisticRegression

regressor = LogisticRegression()
regressor_trnd = regressor.fit(X_train, Y_train)

print("Intercept of the model:", regressor_trnd.intercept_[0]) # intercept
coefs = regressor_trnd.coef_[0]
print("Coef. for age:", coefs[0])
print("Coef. for year of operation:", coefs[1])
print("Coef. for number of nodes:", coefs[2])
# Out:
# Intercept of the model: 0.057255442838151926
# Coef. for age: 0.12621455323937025
# Coef. for year of operation: -0.07267224673474378
# Coef. for number of nodes: 0.8658757248661635

# %% [markdown]
# According to the coefficients of the model we see that the number of node variable has the biggest impact to the survival status and that age and year of operation have little impact on it. However we don't know if any of the coefficients is actually statistically significant (=differs significantly from zero). To check that we use python's statsmodels toolbox.

# %%
# p-values of the coef. using statsmodels:
import statsmodels.api as sm

# adding the columns
X_train_c = df(X_train, columns=["Age", "Year_of_op", "Numb_of_nod"])

# building the model
log_reg_n = sm.Logit(Y_train, X_train_c).fit()

# summary table
print(log_reg_n.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.622843
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:            Surv_status   No. Observations:                  326
# Model:                          Logit   Df Residuals:                      323
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 27 Dec 2022   Pseudo R-squ.:                  0.1014
# Time:                        15:27:04   Log-Likelihood:                -203.05
# converged:                       True   LL-Null:                       -225.97
# Covariance Type:            nonrobust   LLR p-value:                 1.113e-10
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Age             0.1297      0.118      1.097      0.273      -0.102       0.361
# ...

# %% [markdown]
# From the summary table we can see that the first two variables' (=Age and Year of operation) coefficients are not statistically significant (p_values > 0.05). Because of that we drop one input variable at a time and make a new model until there is only statistically significant input variables. We always drop the input variable whom p-value is the highest. In this case first we drop the Year of operation variable.

# %%
# dropping the year of operation variable
X_train_mod = X_train_c.drop(columns="Year_of_op")

# building the model
log_reg_n = sm.Logit(Y_train, X_train_mod).fit()

# summary table
print(log_reg_n.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.623468
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:            Surv_status   No. Observations:                  326
# Model:                          Logit   Df Residuals:                      324
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 27 Dec 2022   Pseudo R-squ.:                  0.1005
# Time:                        15:27:04   Log-Likelihood:                -203.25
# converged:                       True   LL-Null:                       -225.97
# Covariance Type:            nonrobust   LLR p-value:                 1.581e-11
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Age             0.1293      0.118      1.093      0.274      -0.103       0.361
# ...

# %% [markdown]
# Now we can see that the coefficients and the p-values changed little bit. Nevertheless the Age variable's coefficient is still statistically insignificant so next we drop it and make a new estimation.

# %%
# dropping the Age variable
X_train_mod = X_train_mod.drop(columns="Age")

# building the model
log_reg_n = sm.Logit(Y_train, X_train_mod).fit()

# summary table
print(log_reg_n.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.625306
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:            Surv_status   No. Observations:                  326
# Model:                          Logit   Df Residuals:                      325
# Method:                           MLE   Df Model:                            0
# Date:                Tue, 27 Dec 2022   Pseudo R-squ.:                 0.09787
# Time:                        15:27:04   Log-Likelihood:                -203.85
# converged:                       True   LL-Null:                       -225.97
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Numb_of_nod     0.8558      0.146      5.847      0.000       0.569       1.143
# ...

# %% [markdown]
# Now we have the final model where every explanatory variable's coefficient are statistically significant. In our case the final model consist only one explanatory variable which is Number of positive axillary nodes. That means that Age and Year of operation are not relevant when predicting the survival status of the patient. The regression coefficient for that Number of nodes variable is 0.8558.

# %% [markdown]
# Now we construct our final normal logistic regression model and predict the survival status of the test set and compute the figure of merits of the model.

# %%
# modifying the training and testing data
X_train_mod1 = np.delete(X_train, 0, 1) # dropping the Age variable
X_train_mod1 = np.delete(X_train_mod1, 0, 1) # dropping the Year of operation variable
X_test_mod1 = np.delete(X_test, 0, 1) # dropping the Age variable
X_test_mod1 = np.delete(X_test_mod1, 0, 1) # dropping the Year of operation variable

# building the model
log_reg = LogisticRegression()
log_reg_trnd = log_reg.fit(X_train_mod1, Y_train)

# predicting
y_pred = log_reg_trnd.predict(X_test_mod1)
y_pred_prob = log_reg_trnd.predict_proba(X_test_mod1)

# metrics
from sklearn.metrics import confusion_matrix

cm_n = confusion_matrix(Y_test, y_pred) 
print(cm_n)

tn_n, fp_n, fn_n, tp_n = confusion_matrix(Y_test, y_pred).ravel()
print("tn:", tn_n, ",", "fp:", fp_n, ",", "fn:", fn_n, ",", "tp:", tp_n)

# accuracy
from sklearn.metrics import accuracy_score
accuracy_n = accuracy_score(Y_test, y_pred)
print("Accuracy of the normal logreg:", accuracy_n)

# classification report
from sklearn.metrics import classification_report
names = ["surv. status >= 5 years", "surv. status < 5 years"]
print(classification_report(Y_test, y_pred, target_names=names))

# sensibility
from sklearn.metrics import recall_score
sensitivity_n = recall_score(Y_test, y_pred)
print("Sensitivity:", sensitivity_n)
# Out:
# [[46 15]
#  [38 23]]
# tn: 46 , fp: 15 , fn: 38 , tp: 23
# Accuracy of the normal logreg: 0.5655737704918032
#                          precision    recall  f1-score   support
#
# surv. status >= 5 years       0.55      0.75      0.63        61
#  surv. status < 5 years       0.61      0.38      0.46        61
#
#                accuracy                           0.57       122
#               macro avg       0.58      0.57      0.55       122
#            weighted avg       0.58      0.57      0.55       122
#
# Sensitivity: 0.3770491803278688

# %%
# computing the ROC curve and AUC
from sklearn.metrics import roc_curve, auc
fpr_n, tpr_n, treshold_n = roc_curve(Y_test, y_pred_prob[:,1])
auc_n = auc(fpr_n, tpr_n)

# plotting
import matplotlib.pyplot as plt
plt.plot([0, 1], [0, 1], 'r--')
plt.plot(fpr_n, tpr_n, "b", label="AUC: "+str(round(auc_n, 3)))
plt.legend(loc='lower right')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.title("ROC of normal log. reg.")
plt.xlabel("False positive rate"), plt.ylabel("True positive rate")
plt.show()

# %% [markdown]
# **(Just for fun!)** Now let's plot the ROC curve using the training dataset without dropping any input variables and compare the result.

# %%
# building the model
log_reg = LogisticRegression()
log_reg_trnd = log_reg.fit(X_train, Y_train)

# predicting
y_pred = log_reg_trnd.predict(X_test)
y_pred_prob = log_reg_trnd.predict_proba(X_test)

# ROC and AUC
fpr_n, tpr_n, treshold_n = roc_curve(Y_test, y_pred_prob[:,1])
auc_n = auc(fpr_n, tpr_n)

# plotting
plt.plot([0, 1], [0, 1], 'r--')
plt.plot(fpr_n, tpr_n, "b", label="AUC: "+str(round(auc_n, 3)))
plt.legend(loc='lower right')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.title("ROC of normal log. reg. without dropping variables")
plt.xlabel("False positive rate"), plt.ylabel("True positive rate")
plt.show()

# %% [markdown]
# As we can see when comparing the AUCs of the two figures, when removing the statistically insignificant input variables we can improve the performance of the model (at least a little bit).

# %% [markdown]
# **Because we saw that only Number of nodes variable is statistically significant when predicting the survival status of the patient, in next models we use only Number of nodes variable as an explanatory variable.**

# %% [markdown]
# # Logistic ridge regression:

# %% [markdown]
# We start the building of the logistic ridge regression by finding the optimal C-value which is inverse of regularization strenght which means that if C is high there is only small amount of regularization.

# %%
from sklearn.model_selection import GridSearchCV

# cross-validation
logreg_ridge = LogisticRegression(solver='liblinear', penalty='l2') # l2 ridge
parameters = {"C":[1e-4, 1e-2, 1, 5, 10, 20, 30]}
logreg_ridge = GridSearchCV(logreg_ridge, parameters, scoring='accuracy', cv=5)

# training
logreg_ridge_trnd = logreg_ridge.fit(X_train_mod1, Y_train)
print("Optimal C-value:", logreg_ridge_trnd.best_params_)
print("The accuracy score:", logreg_ridge_trnd.best_score_)
# Out:
# Optimal C-value: {'C': 0.0001}
# The accuracy score: 0.6594405594405595

# %% [markdown]
# Now we can build the model and compute the figure of merits.

# %%
# prediction
y_pred = logreg_ridge_trnd.predict(X_test_mod1)
y_pred_prob = logreg_ridge_trnd.predict_proba(X_test_mod1)

# confusion matrix
cm_ridge = confusion_matrix(Y_test, y_pred)
print(cm_ridge)

tn_r, fp_r, fn_r, tp_r = confusion_matrix(Y_test, y_pred).ravel()
print("tn:", tn_r, ",", "fp:", fp_r, ",", "fn:", fn_r, ",", "tp:", tp_r)

# accuracy
accuracy_ridge = accuracy_score(Y_test, y_pred)
print("Accuracy of the ridge logreg:", accuracy_ridge)

# sensibility
sensitivity_ridge = recall_score(Y_test, y_pred)
print("Sensitivity of the ridge logreg:", sensitivity_ridge)

# classification report
print(classification_report(Y_test, y_pred, target_names=names))
# Out:
# [[49 12]
#  [40 21]]
# tn: 49 , fp: 12 , fn: 40 , tp: 21
# Accuracy of the ridge logreg: 0.5737704918032787
# Sensitivity of the ridge logreg: 0.3442622950819672
#                          precision    recall  f1-score   support
#
# surv. status >= 5 years       0.55      0.80      0.65        61
#  surv. status < 5 years       0.64      0.34      0.45        61
#
#                accuracy                           0.57       122
#               macro avg       0.59      0.57      0.55       122
#            weighted avg       0.59      0.57      0.55       122

# %%
# ROC curve and AUC
fpr_ridge, tpr_ridge, treshold = roc_curve(Y_test, y_pred)
auc_ridge = auc(fpr_ridge, tpr_ridge)

# plotting
plt.plot(fpr_ridge, tpr_ridge, 'b', label='AUC: '+str(round(auc_ridge, 3)))
plt.plot([0,1], [0,1], 'r--')
plt.title("ROC of ridge log. reg.")
plt.legend(loc="lower right")
plt.xlabel('False positive rate'), plt.ylabel('True positive rate')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # Logistic lasso regression:

# %% [markdown]
# We start the building of logistic lasso regression model same way as we started to build logistic ridge regression model, by finding the optimal C-value.

# %%
# cross-validation
logreg_lasso = LogisticRegression(solver='liblinear', penalty='l1') # l1 lasso
parameters = {"C":[1e-4, 1e-2, 1, 5, 10, 20, 30]}
logreg_lasso = GridSearchCV(logreg_lasso, parameters, scoring='accuracy', cv=5)

# training
logreg_lasso_trnd = logreg_lasso.fit(X_train_mod1, Y_train)
print("Optimal C-value:", logreg_lasso_trnd.best_params_)
print("The accuracy score:", logreg_lasso_trnd.best_score_)
# Out:
# Optimal C-value: {'C': 1}
# The accuracy score: 0.6624708624708625

# %% [markdown]
# Now we can start to build the model and to compute the figure of merits.

# %%
# predicting
y_pred = logreg_lasso_trnd.predict(X_test_mod1)
y_pred_prob = logreg_lasso_trnd.predict_proba(X_test_mod1)

# confusion matrix
cm_lasso = confusion_matrix(Y_test, y_pred)
print(cm_lasso)

tn_l, fp_l, fn_l, tp_l = confusion_matrix(Y_test, y_pred).ravel()
print("tn:", tn_l, ",", "fp:", fp_l, ",", "fn:", fn_l, ",", "tp:", tp_l)

# accuracy
accuracy_lasso = accuracy_score(Y_test, y_pred)
print("Accuracy of the lasso logreg:", accuracy_lasso)

# sensibility
sensitivity_lasso = recall_score(Y_test, y_pred)
print("Sensitivity of the lasso logreg:", sensitivity_lasso)

# classification report
print(classification_report(Y_test, y_pred, target_names=names))
# Out:
# [[46 15]
#  [38 23]]
# tn: 46 , fp: 15 , fn: 38 , tp: 23
# Accuracy of the lasso logreg: 0.5655737704918032
# Sensitivity of the lasso logreg: 0.3770491803278688
#                          precision    recall  f1-score   support
#
# surv. status >= 5 years       0.55      0.75      0.63        61
#  surv. status < 5 years       0.61      0.38      0.46        61
#
#                accuracy                           0.57       122
#               macro avg       0.58      0.57      0.55       122
#            weighted avg       0.58      0.57      0.55       122

# %%
# ROC curve and AUC
fpr_lasso, tpr_lasso, treshold = roc_curve(Y_test, y_pred)
auc_lasso = auc(fpr_lasso, tpr_lasso)

# plotting
plt.plot(fpr_lasso, tpr_lasso, 'b', label='AUC: '+str(round(auc_lasso, 3)))
plt.plot([0,1], [0,1], 'r--')
plt.title("ROC of lasso log. reg.")
plt.legend(loc="lower right")
plt.xlabel('False positive rate'), plt.ylabel('True positive rate')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # Testing

# %%
# cross-validation
logreg_lasso = LogisticRegression(solver='liblinear', penalty='l1') # l1 lasso
parameters = {"C":[1e-4, 1e-2, 1, 5, 10, 20, 30]}
logreg_lasso = GridSearchCV(logreg_lasso, parameters, scoring='accuracy', cv=5)

# training
logreg_lasso_trnd = logreg_lasso.fit(X_train, Y_train)
print("Optimal C-value:", logreg_lasso_trnd.best_params_)
print("The accuracy score:", logreg_lasso_trnd.best_score_)

# predicting
y_pred = logreg_lasso_trnd.predict(X_test)
y_pred_prob = logreg_lasso_trnd.predict_proba(X_test)

# confusion matrix
cm_lasso = confusion_matrix(Y_test, y_pred)
print(cm_lasso)

tn_l, fp_l, fn_l, tp_l = confusion_matrix(Y_test, y_pred).ravel()
print("tn:", tn_l, ",", "fp:", fp_l, ",", "fn:", fn_l, ",", "tp:", tp_l)

# accuracy
accuracy_lasso = accuracy_score(Y_test, y_pred)
print("Accuracy of the lasso logreg:", accuracy_lasso)

# sensibility
sensitivity_lasso = recall_score(Y_test, y_pred)
print("Sensitivity of the lasso logreg:", sensitivity_lasso)

# classification report
print(classification_report(Y_test, y_pred, target_names=names))

# ROC curve and AUC
fpr_lasso, tpr_lasso, treshold = roc_curve(Y_test, y_pred)
auc_lasso = auc(fpr_lasso, tpr_lasso)

# plotting
plt.plot(fpr_lasso, tpr_lasso, 'b', label='AUC: '+str(round(auc_lasso, 3)))
plt.plot([0,1], [0,1], 'r--')
plt.title("ROC of lasso log. reg.")
plt.legend(loc="lower right")
plt.xlabel('False positive rate'), plt.ylabel('True positive rate')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.show()
# Out:
# Optimal C-value: {'C': 1}
# The accuracy score: 0.6686713286713287
# [[48 13]
#  [37 24]]
# tn: 48 , fp: 13 , fn: 37 , tp: 24
# Accuracy of the lasso logreg: 0.5901639344262295
# Sensitivity of the lasso logreg: 0.39344262295081966
#                          precision    recall  f1-score   support
#
# surv. status >= 5 years       0.56      0.79      0.66        61
#  surv. status < 5 years       0.65      0.39      0.49        61
#
#                accuracy                           0.59       122
#               macro avg       0.61      0.59      0.57       122
#            weighted avg       0.61      0.59      0.57       122

# %% [markdown]
# # Logistic elastic net regression:

# %% [markdown]
# Next we will build and analyze the logistis elastic net regression model which is actually mix of logistic ridge and lasso regressions. We start the building by finding again the optimal C-value and l1 ratio which defines the weight of the ridge and lasso penalty term in the equation.

# %%
from sklearn.linear_model import ElasticNet

# cross-validation
logreg_eln = LogisticRegression(solver="saga", penalty="elasticnet")
parameters = {"C" : [1e-4, 1e-2, 1, 5, 10, 30, 60, 100], "l1_ratio" : np.arange(0, 1, 0.1)}
logreg_eln_cv = GridSearchCV(logreg_eln, parameters, scoring="accuracy", cv=5)

# training
logreg_eln_trnd = logreg_eln_cv.fit(X_train_mod1, Y_train)
print("Optimal C-value and l1 ratio:", logreg_eln_trnd.best_params_)
# Out:
# Optimal C-value and l1 ratio: {'C': 0.01, 'l1_ratio': 0.0}

# %% [markdown]
# Now we can build the model and compute the figure of merits.

# %%
# predicting
y_pred = logreg_eln_trnd.predict(X_test_mod1)
y_pred_prob = logreg_eln_trnd.predict_proba(X_test_mod1)

# confusion matrix
cm_eln = confusion_matrix(Y_test, y_pred)
print(cm_eln)

tn_eln, fp_eln, fn_eln, tp_eln = confusion_matrix(Y_test, y_pred).ravel()
print("tn:", tn_eln, ",", "fp:", fp_eln, ",", "fn:", fn_eln, ",", "tp:", tp_eln)

# accuracy
accuracy_eln = accuracy_score(Y_test, y_pred)
print("Accuracy of the elastic net logreg:", accuracy_eln)

# sensibility
sensitivity_eln = recall_score(Y_test, y_pred)
print("Sensitivity of the elastic net logreg:", sensitivity_eln)

# classification report
print(classification_report(Y_test, y_pred, target_names=names))
# Out:
# [[49 12]
#  [40 21]]
# tn: 49 , fp: 12 , fn: 40 , tp: 21
# Accuracy of the elastic net logreg: 0.5737704918032787
# Sensitivity of the elastic net logreg: 0.3442622950819672
#                          precision    recall  f1-score   support
#
# surv. status >= 5 years       0.55      0.80      0.65        61
#  surv. status < 5 years       0.64      0.34      0.45        61
#
#                accuracy                           0.57       122
#               macro avg       0.59      0.57      0.55       122
#            weighted avg       0.59      0.57      0.55       122

# %%
# ROC curve and AUC
fpr_eln, tpr_eln, treshold = roc_curve(Y_test, y_pred)
auc_eln = auc(fpr_eln, tpr_eln)

# plotting
plt.plot(fpr_eln, tpr_eln, 'b', label='AUC: '+str(round(auc_eln, 3)))
plt.plot([0,1], [0,1], 'r--')
plt.title("ROC of elastic net log. reg.")
plt.legend(loc="lower right")
plt.xlabel('False positive rate'), plt.ylabel('True positive rate')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # Testing

# %%
from sklearn.linear_model import ElasticNet

# cross-validation
logreg_eln = LogisticRegression(solver="saga", penalty="elasticnet")
parameters = {"C" : [1e-4, 1e-2, 1, 5, 10, 30, 60, 100], "l1_ratio" : np.arange(0, 1, 0.1)}
logreg_eln_cv = GridSearchCV(logreg_eln, parameters, scoring="accuracy", cv=5)

# training
logreg_eln_trnd = logreg_eln_cv.fit(X_train, Y_train)
print("Optimal C-value and l1 ratio:", logreg_eln_trnd.best_params_)

# predicting
y_pred = logreg_eln_trnd.predict(X_test)
y_pred_prob = logreg_eln_trnd.predict_proba(X_test)

# confusion matrix
cm_eln = confusion_matrix(Y_test, y_pred)
print(cm_eln)

tn_eln, fp_eln, fn_eln, tp_eln = confusion_matrix(Y_test, y_pred).ravel()
print("tn:", tn_eln, ",", "fp:", fp_eln, ",", "fn:", fn_eln, ",", "tp:", tp_eln)

# accuracy
accuracy_eln = accuracy_score(Y_test, y_pred)
print("Accuracy of the elastic net logreg:", accuracy_eln)

# sensibility
sensitivity_eln = recall_score(Y_test, y_pred)
print("Sensitivity of the elastic net logreg:", sensitivity_eln)

# classification report
print(classification_report(Y_test, y_pred, target_names=names))

# ROC curve and AUC
fpr_eln, tpr_eln, treshold = roc_curve(Y_test, y_pred)
auc_eln = auc(fpr_eln, tpr_eln)

# plotting
plt.plot(fpr_eln, tpr_eln, 'b', label='AUC: '+str(round(auc_eln, 3)))
plt.plot([0,1], [0,1], 'r--')
plt.title("ROC of elastic net log. reg.")
plt.legend(loc="lower right")
plt.xlabel('False positive rate'), plt.ylabel('True positive rate')
plt.xlim([0, 1]), plt.ylim([0, 1])
plt.show()
# Out:
# Optimal C-value and l1 ratio: {'C': 1, 'l1_ratio': 0.2}
# [[48 13]
#  [35 26]]
# tn: 48 , fp: 13 , fn: 35 , tp: 26
# Accuracy of the elastic net logreg: 0.6065573770491803
# Sensitivity of the elastic net logreg: 0.4262295081967213
#                          precision    recall  f1-score   support
#
# surv. status >= 5 years       0.58      0.79      0.67        61
#  surv. status < 5 years       0.67      0.43      0.52        61
#
#                accuracy                           0.61       122
#               macro avg       0.62      0.61      0.59       122
#            weighted avg       0.62      0.61      0.59       122

# %% [markdown]
# # Comparison of the models performance and results:

# %% [markdown]
# Now we compare the results and performances of the different models. Just to refresh the memory, we built four different logistic regression models; normal logistic regression, logistic ridge, lasso and elastic net regression. After building the normal logistic regression model we realised that only variable Number of nodes is statistically significant when predicting the survival status of the patient. Because of that when building and training the other models we used only Number of nodes variable.

# %% [markdown]
# To make it easier to compare the performance of the models, we build a table which consists different figure of merits of the models:

# %%
# constructing the performance comparison table 
table = df()
aucs = [auc_n, auc_ridge, auc_lasso, auc_eln]
sensitivity = [sensitivity_n, sensitivity_ridge, sensitivity_lasso, sensitivity_eln]
accuracy = [accuracy_n, accuracy_ridge, accuracy_lasso, accuracy_eln]
table["AUC"] = aucs
table["Sensitivity"] = sensitivity
table["Accuracy"] = accuracy
table["Log. reg. models"] = ["Normal", "Ridge", "Lasso", "Elastic net"]
table.set_index("Log. reg. models", inplace=True)
print(table)
# Out:
#                        AUC  Sensitivity  Accuracy
# Log. reg. models
# Normal            0.618920     0.377049  0.565574
# Ridge             0.573770     0.344262  0.573770
# Lasso             0.565574     0.377049  0.565574
# Elastic net       0.573770     0.344262  0.573770

# %% [markdown]
# The compare the results we chosed three different figure of merits to keep the comparison more simple. When comparing those scores we can see that actually the normal logistic regression performed really well when comparing to other more complex models. AUC-value is highest in the normal logistic regression model and with the logistic lasso regression it has also highest sensitivity score. Accuracy is not as good as in ridge and elastic net logistic regression but nevertheless really good because the score differs only little bit from those models.

# %% [markdown]
# Also interesting result is that logistic ridge and elastic net regressions has exactly the same scores in every figure of merit and that the normal and lasso logistic regression models has the same scores in every figure of merits but AUC.

# %% [markdown]
# After analyzing the performance of the models **we would choose the normal logistic regression model** as a go to model in our case because it has really good scores in every figure of merits when comparing to other models, especially the AUC score. In addition to good performance it is also more simpler model to build and understand.

# %% [markdown]
# **Comparison of the Number of node variable's coefficient in the different models:**

# %%
print("Coef of normal:", 0.8558)
print("Coef of ridge:", logreg_ridge_trnd.best_estimator_.coef_)
print("Coef of lasso:", logreg_lasso_trnd.best_estimator_.coef_)
print("Coef of elastic net:", logreg_eln_trnd.best_estimator_.coef_)
# Out:
# Coef of normal: 0.8558
# Coef of ridge: [[0.00567028]]
# Coef of lasso: [[0.84550448]]
# Coef of elastic net: [[0.32006698]]

# %% [markdown]
# As we can see the coefficient of the Number of node variable varies a lot between different models. What is not suprising is that the coefficient in normal logistic regression is higher than in other models which is because regularization tends to decrease the values of the coefficients in the model to prevent it to overfit.

# %% [markdown]
# The coefficient in the ridge model is clearly the lowest of which we can deduce that ridge model uses a lot more regularization than the other models. The lasso model seems to use less regularization than the other two models. The thing which is also interesting is that even though the value of the coefficient varies a lot between the models, the performance of the models does not vary as much at all.
